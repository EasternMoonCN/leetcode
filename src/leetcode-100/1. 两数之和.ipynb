# %%
class Solution:
    # O(n^2)
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        n = len(nums)
        for i in range(n):
            for j in range(i + 1, n):
                if nums[i] + nums[j] == target:
                    return [i, j]
        return []

# %%
class Solution:
    ## 这种方式还不行，必须要记住原先的index
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        nums.sort()
        l = 0; r = len(nums) - 1
        while l < r:
            if nums[l] + nums[r] == target:
                return [l, r]
            elif nums[l] + nums[r] > target:
                r -= 1
            else:
                l -= 1
        return [l, r]

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        nums_dict = {}
        for i, num in enumerate(nums):
            if num in nums_dict:
                nums_dict[num].append(i)
            else:
                nums_dict[num] = [i]
        for i, num in enumerate(nums):
            other = target - num
            if other in nums_dict:
                index_list = nums_dict[other]
                for j in index_list:
                    if i != j:
                        return [i, j]
        return []

# %%
class Solution:
    ## 不断便利j，在其左边找一个合适的i（已放入哈希表）
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        nums_dict = {}
        for j, num in enumerate(nums):
            if target - num in nums_dict:
                return [nums_dict[target - num]， j]
            else:
                nums_dict[num] = j
        return []
