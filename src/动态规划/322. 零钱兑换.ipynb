# %%
from typing import List
from math import inf, isinf

# %%
class Solution:
    # 最少的硬币个数
    def coinChange(self, coins: List[int], amount: int) -> int:
        n = len(coins)
        @cache
        def dfs(i: int, amount: int) -> int:
            if i < 0:
                return 0 if amount == 0 else inf
            # 不选
            r2 = dfs(i - 1, amount)
            if amount < coins[i]:
                return r2
            else:
                # 选
                r1 = dfs(i, amount - coins[i]) + 1
                return min(r1, r2)
        r = dfs(n - 1, amount)
        return r if r != inf else -1

# %%
class Solution:
    # 最少的硬币个数
    def coinChange(self, coins: List[int], amount: int) -> int:
        n = len(coins)
        dp = [[inf] * (amount + 1) for _ in range(n + 1)]
        # if i < 0:
        #         return 0 if amount == 0 else inf
        dp[0][0] = 0
        for i in range(n):
            for j in range(amount + 1):
                if j < coins[i]:
                    dp[i + 1][j] = dp[i][j]
                else:
                    dp[i + 1][j] = min(dp[i + 1][j - coins[i]] + 1, dp[i][j])
        return -1 if isinf(dp[n][amount]) else dp[n][amount]

# %%
class Solution:
    # 最少的硬币个数
    def coinChange(self, coins: List[int], amount: int) -> int:
        n = len(coins)
        dp = [inf] * (amount + 1)
        dp[0] = 0
        for i in range(n):
            # 依赖的是当前行的前面，所以要正序（先要把前面算出来）
            for j in range(amount + 1):
                if j >= coins[i]:
                    dp[j] = min(dp[j - coins[i]] + 1, dp[j])
        return -1 if isinf(dp[amount]) else dp[amount]

# %%
class Solution:
    # 最少的硬币个数
    def coinChange(self, coins: List[int], amount: int) -> int:
        n = len(coins)
        dp = [inf] * (amount + 1)
        dp[0] = 0
        for i in range(n):
            # 依赖的是当前行的前面，所以要正序（先要把前面算出来）
            for j in range(coins[i], amount + 1):
                dp[j] = min(dp[j - coins[i]] + 1, dp[j])
        return -1 if isinf(dp[amount]) else dp[amount]
