# %%
from typing import List

# %%
c1 = 'a'
c2 = 'b'
print(ord(c1) + ord(c2))

c3 = chr(97)
print(chr(97))
print(type(c3))

print(str(98))
# Out:
# 195
# a
# <class 'str'>
# 98

# %%
class Solution:
    def equalSubstring(self, s: str, t: str, maxCost: int) -> int:
