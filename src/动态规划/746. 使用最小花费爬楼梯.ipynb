# %%
from functools import cache
from typing import List

# %% [markdown]
# 给你一个整数数组 cost ，其中 cost[i] 是从楼梯第 i 个台阶向上爬需要支付的费用。一旦你支付此费用，即可选择向上爬一个或者两个台阶。
#
# 你可以选择从下标为 0 或下标为 1 的台阶开始爬楼梯。
#
# 请你计算并返回达到楼梯顶部的最低花费。
#
#
#
# 示例 1：
#
# 输入：cost = [10,15,20]
# 输出：15
# 解释：你将从下标为 1 的台阶开始。
# - 支付 15 ，向上爬两个台阶，到达楼梯顶部。
# 总花费为 15 。
# 示例 2：
#
# 输入：cost = [1,100,1,1,1,100,1,1,100,1]
# 输出：6
# 解释：你将从下标为 0 的台阶开始。
# - 支付 1 ，向上爬两个台阶，到达下标为 2 的台阶。
# - 支付 1 ，向上爬两个台阶，到达下标为 4 的台阶。
# - 支付 1 ，向上爬两个台阶，到达下标为 6 的台阶。
# - 支付 1 ，向上爬一个台阶，到达下标为 7 的台阶。
# - 支付 1 ，向上爬两个台阶，到达下标为 9 的台阶。
# - 支付 1 ，向上爬一个台阶，到达楼梯顶部。
# 总花费为 6 。
#
#
# 提示：
#
# 2 <= cost.length <= 1000
# 0 <= cost[i] <= 999

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        @cache
        def dfs(i: int) -> int:
            if i < 0:
                return 1000
            if i <= 1:
                return cost[i]
            return min(dfs(i - 1), dfs(i - 2)) + cost[i]
        # 到达顶层，可以由倒数第一层 或 倒数第二层 到达
        return min(dfs(len(cost) - 1), dfs(len(cost) - 2))

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        cache_dict = {}
        def dfs(i: int) -> int:
            if i in cache_dict:
                return cache_dict[i]
            if i <= 1:
                cache_dict[i] = cost[i]
                return cache_dict[i]
            cache_dict[i] = min(dfs(i - 1), dfs(i - 2)) + cost[i]
            return cache_dict[i]
        # 到达顶层，可以由倒数第一层 或 倒数第二层 到达
        return min(dfs(len(cost) - 1), dfs(len(cost) - 2))

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        n = len(cost)
        dp = [0] * n
        dp[0] = cost[0]
        dp[1] = cost[1]
        for i in range(2, n):
            dp[i] = min(dp[i - 1], dp[i - 2]) + cost[i]
        return min(dp[n - 1], dp[n - 2])

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        n = len(cost)
        f0 = cost[0]
        f1 = cost[1]
        for i in range(2, n):
            f2 = min(f0, f1) + cost[i]
            f0 = f1
            f1 = f2
        return min(f0, f1)

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        @cache
        def dfs(i: int) -> int:
            if i <= 1:
                # 可以从0 或 1 出发，不需要花费费用
                return 0
            # 可以由倒数第一层 加上其花费 或 倒数第二层 加上其花费 到达
            return min(dfs(i - 1) + cost[i - 1], dfs(i - 2) + cost[i - 2])
        # 最终要到达顶n
        return dfs(len(cost))
